# %% [markdown]
# # 自然言語処理
# 非構造データだが統計的な処理をされるものとして自然言語処理がある。
#
# 本項では「形態素解析」「品詞解析」「分かち書き」「構文解析」など基本的な事に加えてTF-IDFとそれを使用したトピック分析を行う
#
# ## ライブラリのインポート

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.datasets import fetch_20newsgroups
from janome.tokenizer import Tokenizer
from googletrans import Translator
import collections
import nltk

# %% [markdown]
# ## 形態素解析
# 日本語での形態素解析を行う。ここで使用する文章はWikipediaの『自然言語処理』とする。

# %%
f = open("sample.txt", encoding="utf-8")
text = f.read()
text
# Out:
# '自然言語処理（しぜんげんごしょり、英語: natural language processing、略称：NLP）は、人間が日常的に使っている自然言語をコンピュータに処理させる一連の技術であり、人工知能と言語学の一分野である。「計算言語学」（computational linguistics）との類似もあるが、自然言語処理は工学的な視点からの言語処理をさすのに対して、計算言語学は言語学的視点を重視する手法をさす事が多い[1]。データベース内の情報を自然言語に変換したり、自然言語の文章をより形式的な（コンピュータが理解しやすい）表現に変換するといった処理が含まれる。応用例としては予測変換、IMEなどの文字変換が挙げられる。\n自然言語の理解をコンピュータにさせることは、自然言語理解とされている。自然言語理解と、自然言語処理の差は、意味を扱うか、扱わないかという説もあったが、最近は数理的な言語解析手法（統計や確率など）が広められた為、パーサ（統語解析器）などが一段と精度や速度が上がり、その意味合いは違ってきている。もともと自然言語の意味論的側面を全く無視して達成できることは非常に限られている。このため、自然言語処理には形態素解析と構文解析、文脈解析、意味解析などをSyntaxなど表層的な観点から解析をする学問であるが、自然言語理解は、意味をどのように理解するかという個々人の理解と推論部分が主な研究の課題になってきており、両者の境界は意思や意図が含まれるかどうかになってきている。 '

# %% [markdown]
# ### 形態素解析

# %%
t = Tokenizer()
for token in t.tokenize(text):
    print(token)
# Out:
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# （	記号,括弧開,*,*,*,*,（,（,（
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# ぜん	名詞,一般,*,*,*,*,ぜん,ゼン,ゼン
# げん	名詞,一般,*,*,*,*,げん,ゲン,ゲン
# ごしょ	動詞,自立,*,*,サ変・−スル,未然ウ接続,ごする,ゴショ,ゴショ
# り	助動詞,*,*,*,文語・リ,基本形,り,リ,リ
# 、	記号,読点,*,*,*,*,、,、,、
# 英語	名詞,一般,*,*,*,*,英語,エイゴ,エイゴ
# :	名詞,サ変接続,*,*,*,*,:,*,*
#  	記号,空白,*,*,*,*, ,*,*
# natural	名詞,固有名詞,組織,*,*,*,natural,*,*
#  	記号,空白,*,*,*,*, ,*,*
# language	名詞,固有名詞,組織,*,*,*,language,*,*
#  	記号,空白,*,*,*,*, ,*,*
# processing	名詞,固有名詞,組織,*,*,*,processing,*,*
# 、	記号,読点,*,*,*,*,、,、,、
# 略称	名詞,サ変接続,*,*,*,*,略称,リャクショウ,リャクショー
# ：	記号,一般,*,*,*,*,：,：,：
# NLP	名詞,固有名詞,組織,*,*,*,NLP,*,*
# ）	記号,括弧閉,*,*,*,*,）,）,）
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 人間	名詞,一般,*,*,*,*,人間,ニンゲン,ニンゲン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 日常	名詞,一般,*,*,*,*,日常,ニチジョウ,ニチジョー
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 使っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,使う,ツカッ,ツカッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# コンピュータ	名詞,一般,*,*,*,*,コンピュータ,コンピュータ,コンピュータ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# せる	動詞,接尾,*,*,一段,基本形,せる,セル,セル
# 一連	名詞,一般,*,*,*,*,一連,イチレン,イチレン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 技術	名詞,一般,*,*,*,*,技術,ギジュツ,ギジュツ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# あり	助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ
# 、	記号,読点,*,*,*,*,、,、,、
# 人工	名詞,一般,*,*,*,*,人工,ジンコウ,ジンコー
# 知能	名詞,一般,*,*,*,*,知能,チノウ,チノー
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 学	名詞,接尾,一般,*,*,*,学,ガク,ガク
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 一	名詞,数,*,*,*,*,一,イチ,イチ
# 分野	名詞,一般,*,*,*,*,分野,ブンヤ,ブンヤ
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# 。	記号,句点,*,*,*,*,。,。,。
# 「	記号,括弧開,*,*,*,*,「,「,「
# 計算	名詞,サ変接続,*,*,*,*,計算,ケイサン,ケイサン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 学	名詞,接尾,一般,*,*,*,学,ガク,ガク
# 」	記号,括弧閉,*,*,*,*,」,」,」
# （	記号,括弧開,*,*,*,*,（,（,（
# computational	名詞,固有名詞,組織,*,*,*,computational,*,*
#  	記号,空白,*,*,*,*, ,*,*
# linguistics	名詞,固有名詞,組織,*,*,*,linguistics,*,*
# ）	記号,括弧閉,*,*,*,*,）,）,）
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 類似	名詞,サ変接続,*,*,*,*,類似,ルイジ,ルイジ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# ある	動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 工学	名詞,一般,*,*,*,*,工学,コウガク,コーガク
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 視点	名詞,一般,*,*,*,*,視点,シテン,シテン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# さす	動詞,自立,*,*,五段・サ行,基本形,さす,サス,サス
# の	名詞,非自立,一般,*,*,*,の,ノ,ノ
# に対して	助詞,格助詞,連語,*,*,*,に対して,ニタイシテ,ニタイシテ
# 、	記号,読点,*,*,*,*,、,、,、
# 計算	名詞,サ変接続,*,*,*,*,計算,ケイサン,ケイサン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 学	名詞,接尾,一般,*,*,*,学,ガク,ガク
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 学	名詞,接尾,一般,*,*,*,学,ガク,ガク
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# 視点	名詞,一般,*,*,*,*,視点,シテン,シテン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 重視	名詞,サ変接続,*,*,*,*,重視,ジュウシ,ジューシ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 手法	名詞,一般,*,*,*,*,手法,シュホウ,シュホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# さす	動詞,自立,*,*,五段・サ行,基本形,さす,サス,サス
# 事	名詞,非自立,一般,*,*,*,事,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 多い	形容詞,自立,*,*,形容詞・アウオ段,基本形,多い,オオイ,オーイ
# [	名詞,サ変接続,*,*,*,*,[,*,*
# 1	名詞,数,*,*,*,*,1,*,*
# ]。	名詞,サ変接続,*,*,*,*,]。,*,*
# データベース	名詞,一般,*,*,*,*,データベース,データベース,データベース
# 内	名詞,接尾,一般,*,*,*,内,ナイ,ナイ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 情報	名詞,一般,*,*,*,*,情報,ジョウホウ,ジョーホー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 変換	名詞,サ変接続,*,*,*,*,変換,ヘンカン,ヘンカン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 文章	名詞,一般,*,*,*,*,文章,ブンショウ,ブンショー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# より	副詞,一般,*,*,*,*,より,ヨリ,ヨリ
# 形式	名詞,一般,*,*,*,*,形式,ケイシキ,ケイシキ
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# （	記号,括弧開,*,*,*,*,（,（,（
# コンピュータ	名詞,一般,*,*,*,*,コンピュータ,コンピュータ,コンピュータ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# やすい	形容詞,非自立,*,*,形容詞・アウオ段,基本形,やすい,ヤスイ,ヤスイ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# 表現	名詞,サ変接続,*,*,*,*,表現,ヒョウゲン,ヒョーゲン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 変換	名詞,サ変接続,*,*,*,*,変換,ヘンカン,ヘンカン
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# といった	助詞,格助詞,連語,*,*,*,といった,トイッタ,トイッタ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 含ま	動詞,自立,*,*,五段・マ行,未然形,含む,フクマ,フクマ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# 。	記号,句点,*,*,*,*,。,。,。
# 応用	名詞,サ変接続,*,*,*,*,応用,オウヨウ,オーヨー
# 例	名詞,一般,*,*,*,*,例,レイ,レイ
# として	助詞,格助詞,連語,*,*,*,として,トシテ,トシテ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 予測	名詞,サ変接続,*,*,*,*,予測,ヨソク,ヨソク
# 変換	名詞,サ変接続,*,*,*,*,変換,ヘンカン,ヘンカン
# 、	記号,読点,*,*,*,*,、,、,、
# IME	名詞,固有名詞,組織,*,*,*,IME,*,*
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 文字	名詞,一般,*,*,*,*,文字,モジ,モジ
# 変換	名詞,サ変接続,*,*,*,*,変換,ヘンカン,ヘンカン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 挙げ	動詞,自立,*,*,一段,未然形,挙げる,アゲ,アゲ
# られる	動詞,接尾,*,*,一段,基本形,られる,ラレル,ラレル
# 。	記号,句点,*,*,*,*,。,。,。
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# コンピュータ	名詞,一般,*,*,*,*,コンピュータ,コンピュータ,コンピュータ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# せる	動詞,接尾,*,*,一段,基本形,せる,セル,セル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# と	助詞,格助詞,一般,*,*,*,と,ト,ト
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 差	名詞,一般,*,*,*,*,差,サ,サ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 意味	名詞,サ変接続,*,*,*,*,意味,イミ,イミ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 扱う	動詞,自立,*,*,五段・ワ行促音便,基本形,扱う,アツカウ,アツカウ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# 、	記号,読点,*,*,*,*,、,、,、
# 扱わ	動詞,自立,*,*,五段・ワ行促音便,未然形,扱う,アツカワ,アツカワ
# ない	助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 説	名詞,一般,*,*,*,*,説,セツ,セツ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# あっ	動詞,自立,*,*,五段・ラ行,連用タ接続,ある,アッ,アッ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 最近	名詞,副詞可能,*,*,*,*,最近,サイキン,サイキン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 数理	名詞,一般,*,*,*,*,数理,スウリ,スーリ
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# 手法	名詞,一般,*,*,*,*,手法,シュホウ,シュホー
# （	記号,括弧開,*,*,*,*,（,（,（
# 統計	名詞,サ変接続,*,*,*,*,統計,トウケイ,トーケイ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 確率	名詞,一般,*,*,*,*,確率,カクリツ,カクリツ
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# ）	記号,括弧閉,*,*,*,*,）,）,）
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 広め	動詞,自立,*,*,一段,未然形,広める,ヒロメ,ヒロメ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 為	名詞,非自立,副詞可能,*,*,*,為,タメ,タメ
# 、	記号,読点,*,*,*,*,、,、,、
# パーサ	名詞,一般,*,*,*,*,パーサ,*,*
# （	記号,括弧開,*,*,*,*,（,（,（
# 統語	名詞,一般,*,*,*,*,統語,トウゴ,トーゴ
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# 器	名詞,接尾,一般,*,*,*,器,キ,キ
# ）	記号,括弧閉,*,*,*,*,）,）,）
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 一段と	副詞,一般,*,*,*,*,一段と,イチダント,イチダント
# 精度	名詞,一般,*,*,*,*,精度,セイド,セイド
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 速度	名詞,一般,*,*,*,*,速度,ソクド,ソクド
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 上がり	動詞,自立,*,*,五段・ラ行,連用形,上がる,アガリ,アガリ
# 、	記号,読点,*,*,*,*,、,、,、
# その	連体詞,*,*,*,*,*,その,ソノ,ソノ
# 意味合い	名詞,一般,*,*,*,*,意味合い,イミアイ,イミアイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 違っ	動詞,自立,*,*,五段・ワ行促音便,連用タ接続,違う,チガッ,チガッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# もともと	副詞,助詞類接続,*,*,*,*,もともと,モトモト,モトモト
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 意味	名詞,サ変接続,*,*,*,*,意味,イミ,イミ
# 論	名詞,接尾,一般,*,*,*,論,ロン,ロン
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# 側面	名詞,一般,*,*,*,*,側面,ソクメン,ソクメン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 全く	副詞,助詞類接続,*,*,*,*,全く,マッタク,マッタク
# 無視	名詞,サ変接続,*,*,*,*,無視,ムシ,ムシ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# 達成	名詞,サ変接続,*,*,*,*,達成,タッセイ,タッセイ
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 非常	名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 限ら	動詞,自立,*,*,五段・ラ行,未然形,限る,カギラ,カギラ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。
# この	連体詞,*,*,*,*,*,この,コノ,コノ
# ため	名詞,非自立,副詞可能,*,*,*,ため,タメ,タメ
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 処理	名詞,サ変接続,*,*,*,*,処理,ショリ,ショリ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 形態素	名詞,一般,*,*,*,*,形態素,ケイタイソ,ケイタイソ
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 構文	名詞,一般,*,*,*,*,構文,コウブン,コーブン
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# 、	記号,読点,*,*,*,*,、,、,、
# 文脈	名詞,一般,*,*,*,*,文脈,ブンミャク,ブンミャク
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# 、	記号,読点,*,*,*,*,、,、,、
# 意味	名詞,サ変接続,*,*,*,*,意味,イミ,イミ
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# Syntax	名詞,固有名詞,組織,*,*,*,Syntax,*,*
# など	助詞,副助詞,*,*,*,*,など,ナド,ナド
# 表層	名詞,一般,*,*,*,*,表層,ヒョウソウ,ヒョーソー
# 的	名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 観点	名詞,一般,*,*,*,*,観点,カンテン,カンテン
# から	助詞,格助詞,一般,*,*,*,から,カラ,カラ
# 解析	名詞,サ変接続,*,*,*,*,解析,カイセキ,カイセキ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# 学問	名詞,サ変接続,*,*,*,*,学問,ガクモン,ガクモン
# で	助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ
# ある	助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル
# が	助詞,接続助詞,*,*,*,*,が,ガ,ガ
# 、	記号,読点,*,*,*,*,、,、,、
# 自然	名詞,形容動詞語幹,*,*,*,*,自然,シゼン,シゼン
# 言語	名詞,一般,*,*,*,*,言語,ゲンゴ,ゲンゴ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 、	記号,読点,*,*,*,*,、,、,、
# 意味	名詞,サ変接続,*,*,*,*,意味,イミ,イミ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# どの	連体詞,*,*,*,*,*,どの,ドノ,ドノ
# よう	名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー
# に	助詞,副詞化,*,*,*,*,に,ニ,ニ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# する	動詞,自立,*,*,サ変・スル,基本形,する,スル,スル
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# という	助詞,格助詞,連語,*,*,*,という,トイウ,トユウ
# 個々人	名詞,一般,*,*,*,*,個々人,ココジン,ココジン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 理解	名詞,サ変接続,*,*,*,*,理解,リカイ,リカイ
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# 推論	名詞,サ変接続,*,*,*,*,推論,スイロン,スイロン
# 部分	名詞,一般,*,*,*,*,部分,ブブン,ブブン
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 主	名詞,形容動詞語幹,*,*,*,*,主,オモ,オモ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 研究	名詞,サ変接続,*,*,*,*,研究,ケンキュウ,ケンキュー
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 課題	名詞,一般,*,*,*,*,課題,カダイ,カダイ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# おり	動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ
# 、	記号,読点,*,*,*,*,、,、,、
# 両者	名詞,一般,*,*,*,*,両者,リョウシャ,リョーシャ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 境界	名詞,一般,*,*,*,*,境界,キョウカイ,キョーカイ
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# 意思	名詞,サ変接続,*,*,*,*,意思,イシ,イシ
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# 意図	名詞,サ変接続,*,*,*,*,意図,イト,イト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 含ま	動詞,自立,*,*,五段・マ行,未然形,含む,フクマ,フクマ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# どう	副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー
# か	助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# なっ	動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# き	動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。

# %% [markdown]
# ### 分かち書き
# 機械学習などで日本語を特徴量とする際に単語で分解してリストに格納することで後述するTF-IDFに使用する。

# %%
wakati = list(t.tokenize(text, wakati=True))
wakati
# Out:
# ['自然',
#  '言語',
#  '処理',
#  '（',
#  'し',
#  'ぜん',
#  'げん',
#  'ごしょ',
#  'り',
#  '、',
#  '英語',
#  ':',
#  ' ',
#  'natural',
#  ' ',
#  'language',
#  ' ',
#  'processing',
#  '、',
#  '略称',
#  '：',
#  'NLP',
#  '）',
#  'は',
#  '、',
#  '人間',
#  'が',
#  '日常',
#  '的',
#  'に',
#  '使っ',
#  'て',
#  'いる',
#  '自然',
#  '言語',
#  'を',
#  'コンピュータ',
#  'に',
#  '処理',
#  'さ',
#  'せる',
#  '一連',
#  'の',
#  '技術',
#  'で',
#  'あり',
#  '、',
#  '人工',
#  '知能',
#  'と',
#  '言語',
#  '学',
#  'の',
#  '一',
#  '分野',
#  'で',
#  'ある',
#  '。',
#  '「',
#  '計算',
#  '言語',
#  '学',
#  '」',
#  '（',
#  'computational',
#  ' ',
#  'linguistics',
#  '）',
#  'と',
#  'の',
#  '類似',
#  'も',
#  'ある',
#  'が',
#  '、',
#  '自然',
#  '言語',
#  '処理',
#  'は',
#  '工学',
#  '的',
#  'な',
#  '視点',
#  'から',
#  'の',
#  '言語',
#  '処理',
#  'を',
#  'さす',
#  'の',
#  'に対して',
#  '、',
#  '計算',
#  '言語',
#  '学',
#  'は',
#  '言語',
#  '学',
#  '的',
#  '視点',
#  'を',
#  '重視',
#  'する',
#  '手法',
#  'を',
#  'さす',
#  '事',
#  'が',
#  '多い',
#  '[',
#  '1',
#  ']。',
#  'データベース',
#  '内',
#  'の',
#  '情報',
#  'を',
#  '自然',
#  '言語',
#  'に',
#  '変換',
#  'し',
#  'たり',
#  '、',
#  '自然',
#  '言語',
#  'の',
#  '文章',
#  'を',
#  'より',
#  '形式',
#  '的',
#  'な',
#  '（',
#  'コンピュータ',
#  'が',
#  '理解',
#  'し',
#  'やすい',
#  '）',
#  '表現',
#  'に',
#  '変換',
#  'する',
#  'といった',
#  '処理',
#  'が',
#  '含ま',
#  'れる',
#  '。',
#  '応用',
#  '例',
#  'として',
#  'は',
#  '予測',
#  '変換',
#  '、',
#  'IME',
#  'など',
#  'の',
#  '文字',
#  '変換',
#  'が',
#  '挙げ',
#  'られる',
#  '。',
#  '\n',
#  '自然',
#  '言語',
#  'の',
#  '理解',
#  'を',
#  'コンピュータ',
#  'に',
#  'さ',
#  'せる',
#  'こと',
#  'は',
#  '、',
#  '自然',
#  '言語',
#  '理解',
#  'と',
#  'さ',
#  'れ',
#  'て',
#  'いる',
#  '。',
#  '自然',
#  '言語',
#  '理解',
#  'と',
#  '、',
#  '自然',
#  '言語',
#  '処理',
#  'の',
#  '差',
#  'は',
#  '、',
#  '意味',
#  'を',
#  '扱う',
#  'か',
#  '、',
#  '扱わ',
#  'ない',
#  'か',
#  'という',
#  '説',
#  'も',
#  'あっ',
#  'た',
#  'が',
#  '、',
#  '最近',
#  'は',
#  '数理',
#  '的',
#  'な',
#  '言語',
#  '解析',
#  '手法',
#  '（',
#  '統計',
#  'や',
#  '確率',
#  'など',
#  '）',
#  'が',
#  '広め',
#  'られ',
#  'た',
#  '為',
#  '、',
#  'パーサ',
#  '（',
#  '統語',
#  '解析',
#  '器',
#  '）',
#  'など',
#  'が',
#  '一段と',
#  '精度',
#  'や',
#  '速度',
#  'が',
#  '上がり',
#  '、',
#  'その',
#  '意味合い',
#  'は',
#  '違っ',
#  'て',
#  'き',
#  'て',
#  'いる',
#  '。',
#  'もともと',
#  '自然',
#  '言語',
#  'の',
#  '意味',
#  '論',
#  '的',
#  '側面',
#  'を',
#  '全く',
#  '無視',
#  'し',
#  'て',
#  '達成',
#  'できる',
#  'こと',
#  'は',
#  '非常',
#  'に',
#  '限ら',
#  'れ',
#  'て',
#  'いる',
#  '。',
#  'この',
#  'ため',
#  '、',
#  '自然',
#  '言語',
#  '処理',
#  'に',
#  'は',
#  '形態素',
#  '解析',
#  'と',
#  '構文',
#  '解析',
#  '、',
#  '文脈',
#  '解析',
#  '、',
#  '意味',
#  '解析',
#  'など',
#  'を',
#  'Syntax',
#  'など',
#  '表層',
#  '的',
#  'な',
#  '観点',
#  'から',
#  '解析',
#  'を',
#  'する',
#  '学問',
#  'で',
#  'ある',
#  'が',
#  '、',
#  '自然',
#  '言語',
#  '理解',
#  'は',
#  '、',
#  '意味',
#  'を',
#  'どの',
#  'よう',
#  'に',
#  '理解',
#  'する',
#  'か',
#  'という',
#  '個々人',
#  'の',
#  '理解',
#  'と',
#  '推論',
#  '部分',
#  'が',
#  '主',
#  'な',
#  '研究',
#  'の',
#  '課題',
#  'に',
#  'なっ',
#  'て',
#  'き',
#  'て',
#  'おり',
#  '、',
#  '両者',
#  'の',
#  '境界',
#  'は',
#  '意思',
#  'や',
#  '意図',
#  'が',
#  '含ま',
#  'れる',
#  'か',
#  'どう',
#  'か',
#  'に',
#  'なっ',
#  'て',
#  'き',
#  'て',
#  'いる',
#  '。']

# %% [markdown]
# ### 品詞
# 分かち書きされて配列に格納された単語に対して品詞を解析する。

# %%
speech = []
for token in t.tokenize(text):
    speech.append(token.part_of_speech.split(',')[0])
print(speech)
# Out:
# ['名詞', '名詞', '名詞', '記号', '動詞', '名詞', '名詞', '動詞', '助動詞', '記号', '名詞', '名詞', '記号', '名詞', '記号', '名詞', '記号', '名詞', '記号', '名詞', '記号', '名詞', '記号', '助詞', '記号', '名詞', '助詞', '名詞', '名詞', '助詞', '動詞', '助詞', '動詞', '名詞', '名詞', '助詞', '名詞', '助詞', '名詞', '動詞', '動詞', '名詞', '助詞', '名詞', '助動詞', '助動詞', '記号', '名詞', '名詞', '助詞', '名詞', '名詞', '助詞', '名詞', '名詞', '助動詞', '助動詞', '記号', '記号', '名詞', '名詞', '名詞', '記号', '記号', '名詞', '記号', '名詞', '記号', '助詞', '助詞', '名詞', '助詞', '動詞', '助詞', '記号', '名詞', '名詞', '名詞', '助詞', '名詞', '名詞', '助動詞', '名詞', '助詞', '助詞', '名詞', '名詞', '助詞', '動詞', '名詞', '助詞', '記号', '名詞', '名詞', '名詞', '助詞', '名詞', '名詞', '名詞', '名詞', '助詞', '名詞', '動詞', '名詞', '助詞', '動詞', '名詞', '助詞', '形容詞', '名詞', '名詞', '名詞', '名詞', '名詞', '助詞', '名詞', '助詞', '名詞', '名詞', '助詞', '名詞', '動詞', '助詞', '記号', '名詞', '名詞', '助詞', '名詞', '助詞', '副詞', '名詞', '名詞', '助動詞', '記号', '名詞', '助詞', '名詞', '動詞', '形容詞', '記号', '名詞', '助詞', '名詞', '動詞', '助詞', '名詞', '助詞', '動詞', '動詞', '記号', '名詞', '名詞', '助詞', '助詞', '名詞', '名詞', '記号', '名詞', '助詞', '助詞', '名詞', '名詞', '助詞', '動詞', '動詞', '記号', '記号', '名詞', '名詞', '助詞', '名詞', '助詞', '名詞', '助詞', '動詞', '動詞', '名詞', '助詞', '記号', '名詞', '名詞', '名詞', '助詞', '動詞', '動詞', '助詞', '動詞', '記号', '名詞', '名詞', '名詞', '助詞', '記号', '名詞', '名詞', '名詞', '助詞', '名詞', '助詞', '記号', '名詞', '助詞', '動詞', '助詞', '記号', '動詞', '助動詞', '助詞', '助詞', '名詞', '助詞', '動詞', '助動詞', '助詞', '記号', '名詞', '助詞', '名詞', '名詞', '助動詞', '名詞', '名詞', '名詞', '記号', '名詞', '助詞', '名詞', '助詞', '記号', '助詞', '動詞', '動詞', '助動詞', '名詞', '記号', '名詞', '記号', '名詞', '名詞', '名詞', '記号', '助詞', '助詞', '副詞', '名詞', '助詞', '名詞', '助詞', '動詞', '記号', '連体詞', '名詞', '助詞', '動詞', '助詞', '動詞', '助詞', '動詞', '記号', '副詞', '名詞', '名詞', '助詞', '名詞', '名詞', '名詞', '名詞', '助詞', '副詞', '名詞', '動詞', '助詞', '名詞', '動詞', '名詞', '助詞', '名詞', '助詞', '動詞', '動詞', '助詞', '動詞', '記号', '連体詞', '名詞', '記号', '名詞', '名詞', '名詞', '助詞', '助詞', '名詞', '名詞', '助詞', '名詞', '名詞', '記号', '名詞', '名詞', '記号', '名詞', '名詞', '助詞', '助詞', '名詞', '助詞', '名詞', '名詞', '助動詞', '名詞', '助詞', '名詞', '助詞', '動詞', '名詞', '助動詞', '助動詞', '助詞', '記号', '名詞', '名詞', '名詞', '助詞', '記号', '名詞', '助詞', '連体詞', '名詞', '助詞', '名詞', '動詞', '助詞', '助詞', '名詞', '助詞', '名詞', '助詞', '名詞', '名詞', '助詞', '名詞', '助動詞', '名詞', '助詞', '名詞', '助詞', '動詞', '助詞', '動詞', '助詞', '動詞', '記号', '名詞', '助詞', '名詞', '助詞', '名詞', '助詞', '名詞', '助詞', '動詞', '動詞', '助詞', '副詞', '助詞', '助詞', '動詞', '助詞', '動詞', '助詞', '動詞', '記号']

# %% [markdown]
# ### 使用された単語の出現回数

# %%
cnt = collections.Counter(wakati)
for row in cnt:
    print(row+"\t= "+str(cnt[row]))
# Out:
# 自然	= 12
# 言語	= 18
# 処理	= 7
# （	= 5
# し	= 4
# ぜん	= 1
# げん	= 1
# ごしょ	= 1
# り	= 1
# 、	= 21
# 英語	= 1
# :	= 1
#  	= 4
# natural	= 1
# language	= 1
# processing	= 1
# 略称	= 1
# ：	= 1
# NLP	= 1
# ）	= 5
# は	= 12
# 人間	= 1
# が	= 13
# 日常	= 1
# 的	= 7
# に	= 10
# 使っ	= 1
# て	= 10
# いる	= 5
# を	= 12
# コンピュータ	= 3
# さ	= 3
# せる	= 2
# 一連	= 1
# の	= 14
# 技術	= 1
# で	= 3
# あり	= 1
# 人工	= 1
# 知能	= 1
# と	= 6
# 学	= 4
# 一	= 1
# 分野	= 1
# ある	= 3
# 。	= 7
# 「	= 1
# 計算	= 2
# 」	= 1
# computational	= 1
# linguistics	= 1
# 類似	= 1
# も	= 2
# 工学	= 1
# な	= 5
# 視点	= 2
# から	= 2
# さす	= 2
# に対して	= 1
# 重視	= 1
# する	= 4
# 手法	= 2
# 事	= 1
# 多い	= 1
# [	= 1
# 1	= 1
# ]。	= 1
# データベース	= 1
# 内	= 1
# 情報	= 1
# 変換	= 4
# たり	= 1
# 文章	= 1
# より	= 1
# 形式	= 1
# 理解	= 7
# やすい	= 1
# 表現	= 1
# といった	= 1
# 含ま	= 2
# れる	= 2
# 応用	= 1
# 例	= 1
# として	= 1
# 予測	= 1
# IME	= 1
# など	= 5
# 文字	= 1
# 挙げ	= 1
# られる	= 1
#
# 	= 1
# こと	= 2
# れ	= 2
# 差	= 1
# 意味	= 4
# 扱う	= 1
# か	= 5
# 扱わ	= 1
# ない	= 1
# という	= 2
# 説	= 1
# あっ	= 1
# た	= 2
# 最近	= 1
# 数理	= 1
# 解析	= 7
# 統計	= 1
# や	= 3
# 確率	= 1
# 広め	= 1
# られ	= 1
# 為	= 1
# パーサ	= 1
# 統語	= 1
# 器	= 1
# 一段と	= 1
# 精度	= 1
# 速度	= 1
# 上がり	= 1
# その	= 1
# 意味合い	= 1
# 違っ	= 1
# き	= 3
# もともと	= 1
# 論	= 1
# 側面	= 1
# 全く	= 1
# 無視	= 1
# 達成	= 1
# できる	= 1
# 非常	= 1
# 限ら	= 1
# この	= 1
# ため	= 1
# 形態素	= 1
# 構文	= 1
# 文脈	= 1
# Syntax	= 1
# 表層	= 1
# 観点	= 1
# 学問	= 1
# どの	= 1
# よう	= 1
# 個々人	= 1
# 推論	= 1
# 部分	= 1
# 主	= 1
# 研究	= 1
# 課題	= 1
# なっ	= 2
# おり	= 1
# 両者	= 1
# 境界	= 1
# 意思	= 1
# 意図	= 1
# どう	= 1

# %% [markdown]
# ### 使用された品詞の出現回数

# %%
cnt = collections.Counter(speech)
for row in cnt:
    print(row+"\t= "+str(cnt[row]))
# Out:
# 名詞	= 156
# 記号	= 46
# 動詞	= 46
# 助動詞	= 15
# 助詞	= 99
# 形容詞	= 2
# 副詞	= 5
# 連体詞	= 3

# %% [markdown]
# ## 構文解析
# 形態素解析の結果得られた単語に対して単語の関係性を解析する。
#
# ただし、日本語に対応するライブラリは環境によって使用の可否が変わるため英語の文章で行う。

# %%
nltk.download("punkt")
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\decar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\decar\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = "There are two chickens in the garden."
words = nltk.word_tokenize(text)
words_parsed = nltk.pos_tag(words)
words_parsed
# Out:
# [('There', 'EX'),
#  ('are', 'VBP'),
#  ('two', 'CD'),
#  ('chickens', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('garden', 'NN'),
#  ('.', '.')]

# %% [markdown]
# 得られた結果についてEXは存在、VBPは三人称単数以外の動詞、CDは基数、NNSは複数形の名刺、INは前置詞または従属接続詞、DTは限定詞、NNは名詞を表す。
#
# なお、ここに現れていない他の構文解析結果の品詞はここを参照：https://www.ibm.com/docs/ja/wca/3.5.0?topic=analytics-part-speech-tag-sets

# %% [markdown]
# ## TFとTF-IDFとトピック分析
# 自然言語を使った文書分類での特徴量では単語のTF値(出現頻度)やTF-IDF(出現頻度と文書逆頻度の積)を使用される。
#
# ここではあらかじめ文章のジャンルは分からないものとして教師なし学習で単語のトピック分析を行う。

# %%
data = fetch_20newsgroups(remove=("headers", "footers", "quotes"))
n_topics = 20

# %% [markdown]
# ### TF
# 文章における単語の出現頻度を特徴量とている。

# %%
tf_vec = CountVectorizer(max_features=1000, stop_words="english")
tf = tf_vec.fit_transform(data.data)

# %% [markdown]
# ### TF-IDF
# IDFは文章における逆頻度を指す。意図としては、単語の出現回数が多くてもどの文章にも表れている訳ではなく単語が他の文章に現れないレアな単語を探すことができる。

# %%
tfidf_vec = TfidfVectorizer(max_features=1000, stop_words="english")
tfidf = tfidf_vec.fit_transform(data.data)

# %% [markdown]
# ### LDA

# %%
model_tf = LDA(n_components=n_topics)
model_tf.fit(tf)
# Out:
# LatentDirichletAllocation(n_components=20)

# %%
model_tfidf = LDA(n_components=n_topics)
model_tfidf.fit(tfidf)
# Out:
# LatentDirichletAllocation(n_components=20)

# %% [markdown]
# ### TF値によるトピック分析

# %%
features = tf_vec.get_feature_names()
for i in range(20):
    print("topic %d:"%(i+1))
    row = model_tf.components_[i]
    for j in row.argsort()[:-20-1:-1]:
        print(features[j], end=" ")
    print()
# Out:
# topic 1:
# people mr think government don right know going president just state rights stephanopoulos did make like want say israel time
# topic 2:
# game just year good like team don think games time play got better season players know hockey ve really ll
# topic 3:
# said people armenian didn know armenians just went don did time like told saw came took day say going started
# topic 4:
# file program available image ftp files edu space pub nasa output entry information format directory info version source images use
# topic 5:
# edu com 00 mail list send new email cs ca 50 sale offer shipping interested uk address ac article condition
# topic 6:
# key chip encryption keys clipper government use security law public algorithm des escrow phone nsa secure bit number enforcement used
# topic 7:
# data software bit mac use internet anonymous pc computer ibm hardware users available information mail os unix systems 32 standard
# topic 8:
# scsi law jesus ide bus paul word david controller drive day mark john transfer 16 did hear way does dead
# topic 9:
# new national 1993 research information center university april states space american united launch state technology health 1992 government public years
# topic 10:
# drive disk hard drives cx w7 floppy dos tape controller mb 17 pin keyboard power price rom card supply cable
# topic 11:
# jews book turkish jewish world history greek books turkey war land israel turks years anti new population letter published number
# topic 12:
# ax max g9v pl b8f 1t 3t bhj giz a86 75u 7ey 2tm 1d9 6ei gk 0t 34u 9v wm
# topic 13:
# thanks know does card like need help looking video just mail use hi memory advance don windows work driver board
# topic 14:
# god people believe jesus does think say bible christian don life just know church true faith christians religion christ like
# topic 15:
# car gun guns 000 control cars like don used water crime engine weapons good just firearms people rate use year
# topic 16:
# 10 25 12 15 11 20 16 14 13 18 17 24 30 55 21 23 19 40 22 26
# topic 17:
# db space bike earth gm orbit light unit black dc power bh mass cs good al radio air cross gas
# topic 18:
# don like use just think does problem case make question good time point work science people used way know cause
# topic 19:
# ax b8f 145 a86 1d9 34u pl 0t g9v 2di wm ah sl 0d 1t 75u bxn 7u 2tm chz
# topic 20:
# windows window use using problem application set screen like program display widget running motif server work code does mouse just

# %% [markdown]
# ### TF-IDFによるトピック分析

# %%
features = tfidf_vec.get_feature_names()
for i in range(20):
    print("topic %d:"%(i+1))
    row = model_tfidf.components_[i]
    for j in row.argsort()[:-20-1:-1]:
        print(features[j], end=" ")
    print()
# Out:
# topic 1:
# ground wire women mr claim men news said posted saw explain la line certainly job details post did answer look
# topic 2:
# drive card windows use video monitor disk mac like scsi pc memory software thanks apple problem does know used need
# topic 3:
# key chip clipper encryption keys nsa phone algorithm escrow chips secure des government security secret use number privacy technology public
# topic 4:
# car window cars use server like problem just windows engine good application know ve work don display road widget using
# topic 5:
# 00 10 11 15 12 20 23 25 14 17 april 30 13 18 50 21 16 19 1993 24
# topic 6:
# com dave vs article game edu gov gm apr david ca 1993 93 ma al canada night 03 hockey internet
# topic 7:
# mike hear 800 ll year pittsburgh just switch high better lines sure dc try make guess quality trade mode season
# topic 8:
# mouse keyboard ac steve com thank uk weeks cable white newsgroup usenet thanks email ask page haven request mail simple
# topic 9:
# government people gun armenian law armenians clinton president turkish state states federal tax crime said guns police turkey country public
# topic 10:
# file files program windows ftp dos directory thanks use gif format know does image help using site code pub anybody
# topic 11:
# people don think just like know say time right things make evidence does point really good way believe did person
# topic 12:
# thanks mail advance address know does send hi looking info email appreciated anybody post reply appreciate information tell edu interested
# topic 13:
# israel jews israeli jewish water alt mean peace atheism wasn land agree jpeg asked war anti aren faq couldn act
# topic 14:
# guy radio like ax sound hot happen sounds doesn rest letter driver lots tv case killed didn gun source police
# topic 15:
# space edu information graphics data available sun nasa orbit internet com book university software code comp launch source computer sci
# topic 16:
# edu fbi cs ah started think mac true gas add list pay university story quite published define class david building
# topic 17:
# god jesus bible christian christ christians church believe faith life hell people love christianity man sin say does don lord
# topic 18:
# team game year think players games just don good play like season time years got hockey win hit teams know
# topic 19:
# bike soon edu dod good condition just don test blood new like sale cover know isn asking time contact cost
# topic 20:
# deleted just posting stuff jim check net did thought hours friend base called sort buy getting thanks like wrong post

# %% [markdown]
# ## 機械翻訳
# 分析対象あるいはモデルの作成について一つの言語で行っていても、他の言語でないと資料が無く和訳しないといけない事がある。そこで、GoogleTransAPIを使用して他言語で書かれた文章を対象の言語に翻訳する。ここでは英語のwikipediaの「Natural Langage Processing」について和訳する。

# %%
f = open("sample_en.txt", "r")
english = f.read()
english
# Out:
# 'Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data. The goal is a computer capable of "understanding" the contents of documents, including the contextual nuances of the language within them. The technology can then accurately extract information and insights contained in the documents as well as categorize and organize the documents themselves.\n\nChallenges in natural language processing frequently involve speech recognition, natural-language understanding, and natural-language generation. '

# %%
trans = Translator()

# %%
trans.raise_Exception = True
japanese = trans.translate(english,dest="ja")
japanese.text
# Out:
# '自然言語処理（NLP）は、コンピューターと人間の言語間の相互作用に関係する言語学、コンピューターサイエンス、および人工知能のサブフィールド、特にコンピューターをプログラムして大量の自然言語データを処理および分析する方法です。目標は、文書の内容を「理解」できるコンピューターです。このテクノロジーは、ドキュメントに含まれる情報と洞察を正確に抽出し、ドキュメント自体を分類および整理することができます。\n\n自然言語処理の課題には、音声認識、自然言語の理解、自然言語の生成が頻繁に含まれます。'
